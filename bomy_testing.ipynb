# %% [markdown]
# # Framework Testing

# %%
import bomy as bom

# Get the latest 5 daily closes of IBIT
data = bom.yfd('IBIT', '2025-01-23')
# Out:
# 2025-01-30 23:27:41: bomyPandas init...
# 2025-01-30 23:27:41:  <class 'pandas.core.frame.DataFrame'>
# 2025-01-30 23:27:41: bomyPandas columns -->
# ---------------------------------------
# ts_date: datetime64[ns, America/New_York]
# Open: float64
# High: float64
# Low: float64
# Close: float64
# Adj Close: float64
# Volume: int64
# Dividends: float64
# Stock Splits: float64
# Capital Gains: float64
# ---------------------------------------
# 2025-01-30 23:27:41: bomyPandas done...

# %%
data
# Out:
#                     ts_date       Open       High        Low      Close  \
# 0 2025-01-23 00:00:00-05:00  58.230000  60.820000  58.160000  58.790001
# 1 2025-01-24 00:00:00-05:00  59.919998  61.060001  59.560001  59.700001
# 2 2025-01-27 00:00:00-05:00  57.320000  58.200001  56.150002  57.669998
# 3 2025-01-28 00:00:00-05:00  58.340000  59.060001  57.544998  57.580002
# 4 2025-01-29 00:00:00-05:00  58.119999  59.669998  57.660000  59.340000
#
#    Adj Close     Volume  Dividends  Stock Splits  Capital Gains
# 0  58.790001  118197600        0.0           0.0            0.0
# 1  59.700001   46082300        0.0           0.0            0.0
# 2  57.669998   61243100        0.0           0.0            0.0
# 3  57.580002   30257000        0.0           0.0            0.0
# 4  59.340000   37866900        0.0           0.0            0.0

# %%
import numpy as np
data['log_ret'] = np.log(data['Close'] / data['Close'].shift(1))

# %%
std = data['log_ret'].std()*252**0.5
std
# Out:
# np.float64(0.4414540051524894)

# %% [markdown]
# ## Read/Review Data

# %%
import os
import pandas as pd
import sqlite3

dfh_path = './static/hl-funding.db'
connection = sqlite3.connect(dfh_path)
dfh = pd.read_sql_query("SELECT * FROM [hyperliquid-funding]", connection)
dfh[dfh['market'] == 'SOL']
# Out:
#                  Timestamp market  fundingrate       apy
# 101    2024-10-28 02:41:59    SOL     0.000013  0.108000
# 252    2024-10-28 02:42:02    SOL     0.000013  0.108000
# 421    2024-10-28 03:06:02    SOL     0.000013  0.108000
# 575    2024-10-28 04:06:02    SOL     0.000013  0.108000
# 699    2024-10-28 05:06:02    SOL     0.000013  0.108000
# ...                    ...    ...          ...       ...
# 61179  2024-11-13 18:06:03    SOL     0.000150  1.292026
# 61333  2024-11-13 19:06:03    SOL     0.000140  1.209514
# 61527  2024-11-13 20:06:03    SOL     0.000019  0.166493
# 61740  2024-11-13 21:06:02    SOL     0.000013  0.108000
# 61819  2024-11-13 22:06:03    SOL     0.000043  0.374976
#
# [406 rows x 4 columns]

# %%
import os
import pandas as pd
import sqlite3

df_path = './static/dydx-funding.db'
connection = sqlite3.connect(df_path)
df = pd.read_sql_query("SELECT * FROM [dydx-funding]", connection)
df.tail(50)
# Out:
#                  Timestamp     market  fundingrate  apy
# 99890  2024-11-13 21:05:03    BTC-USD          0.0  0.0
# 99891  2024-11-13 21:05:03    ADA-USD          0.0  0.0
# 99892  2024-11-13 21:05:03   CELO-USD          0.0  0.0
# 99893  2024-11-13 21:05:03    FIL-USD          0.0  0.0
# 99894  2024-11-13 21:05:03   ALGO-USD          0.0  0.0
# 99895  2024-11-13 21:05:03  1INCH-USD          0.0  0.0
# 99896  2024-11-13 21:05:03    TRX-USD          0.0  0.0
# 99897  2024-11-13 21:05:03    MKR-USD          0.0  0.0
# 99898  2024-11-13 21:05:03    XTZ-USD          0.0  0.0
# 99899  2024-11-13 21:05:03  SUSHI-USD          0.0  0.0
# 99900  2024-11-13 21:05:03    XMR-USD          0.0  0.0
# 99901  2024-11-13 21:05:03   AVAX-USD          0.0  0.0
# 99902  2024-11-13 22:05:03    ZEC-USD          0.0  0.0
# 99903  2024-11-13 22:05:03    YFI-USD          0.0  0.0
# 99904  2024-11-13 22:05:03   ATOM-USD          0.0  0.0
# 99905  2024-11-13 22:05:03    CRV-USD          0.0  0.0
# 99906  2024-11-13 22:05:03    DOT-USD          0.0  0.0
# 99907  2024-11-13 22:05:03    BCH-USD          0.0  0.0
# 99908  2024-11-13 22:05:03    ETH-USD          0.0  0.0
# 99909  2024-11-13 22:05:03    ZRX-USD          0.0  0.0
# 99910  2024-11-13 22:05:03    SNX-USD          0.0  0.0
# 99911  2024-11-13 22:05:03   DOGE-USD          0.0  0.0
# 99912  2024-11-13 22:05:03    EOS-USD          0.0  0.0
# 99913  2024-11-13 22:05:03    XLM-USD          0.0  0.0
# 99914  2024-11-13 22:05:03   AAVE-USD          0.0  0.0
# 99915  2024-11-13 22:05:03   NEAR-USD          0.0  0.0
# 99916  2024-11-13 22:05:03  MATIC-USD          0.0  0.0
# 99917  2024-11-13 22:05:03   RUNE-USD          0.0  0.0
# 99918  2024-11-13 22:05:03    UMA-USD          0.0  0.0
# 99919  2024-11-13 22:05:03    UNI-USD          0.0  0.0
# 99920  2024-11-13 22:05:03   LINK-USD          0.0  0.0
# 99921  2024-11-13 22:05:03    ICP-USD          0.0  0.0
# 99922  2024-11-13 22:05:03   LUNA-USD          0.0  0.0
# 99923  2024-11-13 22:05:03    LTC-USD          0.0  0.0
# 99924  2024-11-13 22:05:03   COMP-USD          0.0  0.0
# 99925  2024-11-13 22:05:03    ETC-USD          0.0  0.0
# 99926  2024-11-13 22:05:03    SOL-USD          0.0  0.0
# 99927  2024-11-13 22:05:03    ENJ-USD          0.0  0.0
# 99928  2024-11-13 22:05:03    BTC-USD          0.0  0.0
# 99929  2024-11-13 22:05:03    ADA-USD          0.0  0.0
# 99930  2024-11-13 22:05:03   CELO-USD          0.0  0.0
# 99931  2024-11-13 22:05:03    FIL-USD          0.0  0.0
# 99932  2024-11-13 22:05:03   ALGO-USD          0.0  0.0
# 99933  2024-11-13 22:05:03  1INCH-USD          0.0  0.0
# 99934  2024-11-13 22:05:03    TRX-USD          0.0  0.0
# 99935  2024-11-13 22:05:03    MKR-USD          0.0  0.0
# 99936  2024-11-13 22:05:03    XTZ-USD          0.0  0.0
# 99937  2024-11-13 22:05:03  SUSHI-USD          0.0  0.0
# 99938  2024-11-13 22:05:03    XMR-USD          0.0  0.0
# 99939  2024-11-13 22:05:03   AVAX-USD          0.0  0.0
